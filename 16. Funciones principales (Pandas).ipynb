# %%
import pandas as pd

csv = pd.read_csv('bestsellers-with-categories.csv')
csv
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
round(csv.describe(), 2)
# Out:
#        User Rating   Reviews   Price     Year
# count       550.00    550.00  550.00   550.00
# mean          4.62  11953.28   13.10  2014.00
# std           0.23  11731.13   10.84     3.17
# min           3.30     37.00    0.00  2009.00
# 25%           4.50   4058.00    7.00  2011.00
# 50%           4.70   8580.00   11.00  2014.00
# 75%           4.80  17253.25   16.00  2017.00
# max           4.90  87841.00  105.00  2019.00

# %%
csv.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
csv.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
csv.sample(5, random_state=25)
# Out:
#                                                   Name  \
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# 377  The Four Agreements: A Practical Guide to Pers...
# 280  Publication Manual of the American Psychologic...
# 234             Mindset: The New Psychology of Success
# 77                               Divergent / Insurgent
#
#                                  Author  User Rating  Reviews  Price  Year  \
# 6                   George R. R. Martin          4.7    19735     30  2014
# 377                     Don Miguel Ruiz          4.7    23308      6  2016
# 280  American Psychological Association          4.5     8580     46  2018
# 234                      Carol S. Dweck          4.6     5542     10  2015
# 77                        Veronica Roth          4.5    17684      6  2014
#
#            Genre
# 6        Fiction
# 377  Non Fiction
# 280  Non Fiction
# 234  Non Fiction
# 77       Fiction

# %%
csv.memory_usage(deep=True)
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %%
csv.Author.value_counts()
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: Author, Length: 248, dtype: int64

# %%
# Duplicar un registro
csv.iloc[0]
csv = csv.append(csv.iloc[0], ignore_index=True)
csv.tail()
# Out:
# C:\Users\jorge\AppData\Local\Temp\ipykernel_9256\1263080183.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   csv = csv.append(csv.iloc[0], ignore_index=True)
#                                                   Name       Author  \
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 550                      10-Day Green Smoothie Cleanse     JJ Smith
# 551                      10-Day Green Smoothie Cleanse     JJ Smith
#
#      User Rating  Reviews  Price  Year        Genre
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction
# 550          4.7    17350      8  2016  Non Fiction
# ...

# %%
# Eliminar duplicados
csv.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Ordenar por año
csv.sort_values('Year')
# Out:
#                                                   Name            Author  \
# 513               Twilight (The Twilight Saga, Book 1)   Stephenie Meyer
# 418  The Last Olympian (Percy Jackson and the Olymp...      Rick Riordan
# 177                                      I, Alex Cross   James Patterson
# 417                                   The Last Lecture      Randy Pausch
# 331  The 7 Habits of Highly Effective People: Power...  Stephen R. Covey
# ..                                                 ...               ...
# 150                                               Guts  Raina Telgemeier
# 466  The Subtle Art of Not Giving a F*ck: A Counter...       Mark Manson
# 462                                 The Silent Patient  Alex Michaelides
# 130  Girl, Wash Your Face: Stop Believing the Lies ...     Rachel Hollis
# 155  Harry Potter and the Goblet of Fire: The Illus...     J. K. Rowling
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
# Ordenar por año descendiente
csv.sort_values('Year', ascending=False)
# Out:
#                                                   Name                 Author  \
# 380  The Four Agreements: A Practical Guide to Pers...        Don Miguel Ruiz
# 263    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 491                                   The Wonky Donkey            Craig Smith
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
# 267             Player's Handbook (Dungeons & Dragons)       Wizards RPG Team
# ..                                                 ...                    ...
# 369  The Five Dysfunctions of a Team: A Leadership ...       Patrick Lencioni
# 374  The Five Love Languages: How to Express Heartf...           Gary Chapman
# 160                  Have a Little Faith: A True Story            Mitch Albom
# 92   Eat This, Not That! Thousands of Simple Food S...        David Zinczenko
# 418  The Last Olympian (Percy Jackson and the Olymp...           Rick Riordan
#
# ...

# %%
# Sesgo
csv['User Rating'].skew()
# Out:
# -1.5075394905940473
